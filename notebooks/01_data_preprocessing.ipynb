# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns
campaigns = pd.read_csv("../shopee_campaigns_thailand.csv")
order_items = pd.read_csv("../shopee_order_items_thailand.csv")
orders = pd.read_csv("../shopee_orders_thailand.csv")
customers = pd.read_csv("../shopee_customers_thailand.csv")
products = pd.read_csv("../shopee_products_thailand.csv")
product_campaigns = pd.read_csv("../shopee_product_campaign_thailand.csv")
sellers = pd.read_csv("../shopee_sellers_thailand.csv")
shipments = pd.read_csv("../shopee_shipments_thailand.csv")
